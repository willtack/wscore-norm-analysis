# %%
import seaborn as sns
import pandas as pd

data = pd.read_csv("data.csv")

# %%
sns.scatterplot(data=data, x="mean w-score", y="perc_suprathreshold")
# Out:
# <AxesSubplot:xlabel='mean w-score', ylabel='perc_suprathreshold'>

# %%
# create column of network names

# %%
name_list = list(data['label_full_name'])
name_list
# Out:
# ['17Networks_LH_VisCent_ExStr_1',
#  '17Networks_LH_VisCent_ExStr_2',
#  '17Networks_LH_VisCent_Striate_1',
#  '17Networks_LH_VisCent_ExStr_3',
#  '17Networks_LH_VisCent_ExStr_4',
#  '17Networks_LH_VisCent_ExStr_5',
#  '17Networks_LH_VisPeri_ExStrInf_1',
#  '17Networks_LH_VisPeri_ExStrInf_2',
#  '17Networks_LH_VisPeri_ExStrInf_3',
#  '17Networks_LH_VisPeri_StriCal_1',
#  '17Networks_LH_VisPeri_ExStrSup_1',
#  '17Networks_LH_VisPeri_ExStrSup_2',
#  '17Networks_LH_SomMotA_1',
#  '17Networks_LH_SomMotA_2',
#  '17Networks_LH_SomMotA_3',
#  '17Networks_LH_SomMotA_4',
#  '17Networks_LH_SomMotA_5',
#  '17Networks_LH_SomMotA_6',
#  '17Networks_LH_SomMotA_7',
#  '17Networks_LH_SomMotA_8',
#  '17Networks_LH_SomMotB_Aud_1',
#  '17Networks_LH_SomMotB_Aud_2',
#  '17Networks_LH_SomMotB_S2_1',
#  '17Networks_LH_SomMotB_S2_2',
#  '17Networks_LH_SomMotB_Aud_3',
#  '17Networks_LH_SomMotB_S2_3',
#  '17Networks_LH_SomMotB_Cent_1',
#  '17Networks_LH_SomMotB_Cent_2',
#  '17Networks_LH_DorsAttnA_TempOcc_1',
#  '17Networks_LH_DorsAttnA_TempOcc_2',
#  '17Networks_LH_DorsAttnA_ParOcc_1',
#  '17Networks_LH_DorsAttnA_SPL_1',
#  '17Networks_LH_DorsAttnA_SPL_2',
#  '17Networks_LH_DorsAttnA_SPL_3',
#  '17Networks_LH_DorsAttnB_PostC_1',
#  '17Networks_LH_DorsAttnB_PostC_2',
#  '17Networks_LH_DorsAttnB_PostC_3',
#  '17Networks_LH_DorsAttnB_PostC_4',
#  '17Networks_LH_DorsAttnB_FEF_1',
#  '17Networks_LH_SalVentAttnA_ParOper_1',
#  '17Networks_LH_SalVentAttnA_Ins_1',
#  '17Networks_LH_SalVentAttnA_FrOper_1',
#  '17Networks_LH_SalVentAttnA_FrOper_2',
#  '17Networks_LH_SalVentAttnA_ParMed_1',
#  '17Networks_LH_SalVentAttnA_FrMed_1',
#  '17Networks_LH_SalVentAttnA_FrMed_2',
#  '17Networks_LH_SalVentAttnB_IPL_1',
#  '17Networks_LH_SalVentAttnB_PFCl_1',
#  '17Networks_LH_SalVentAttnB_Ins_1',
#  '17Networks_LH_SalVentAttnB_PFCmp_1',
#  '17Networks_LH_LimbicB_OFC_1',
#  '17Networks_LH_LimbicB_OFC_2',
#  '17Networks_LH_LimbicA_TempPole_1',
#  '17Networks_LH_LimbicA_TempPole_2',
#  '17Networks_LH_LimbicA_TempPole_3',
#  '17Networks_LH_LimbicA_TempPole_4',
#  '17Networks_LH_ContA_Temp_1',
#  '17Networks_LH_ContA_IPS_1',
#  '17Networks_LH_ContA_IPS_2',
#  '17Networks_LH_ContA_IPS_3',
#  '17Networks_LH_ContA_PFCd_1',
#  '17Networks_LH_ContA_PFClv_1',
#  '17Networks_LH_ContA_PFCl_1',
#  '17Networks_LH_ContA_PFCl_2',
#  '17Networks_LH_ContA_PFCl_3',
#  '17Networks_LH_ContA_Cingm_1',
#  '17Networks_LH_ContB_Temp_1',
#  '17Networks_LH_ContB_IPL_1',
#  '17Networks_LH_ContB_PFCl_1',
#  '17Networks_LH_ContB_PFClv_1',
#  '17Networks_LH_ContB_PFClv_2',
#  '17Networks_LH_ContC_pCun_1',
#  '17Networks_LH_ContC_pCun_2',
#  '17Networks_LH_ContC_Cingp_1',
#  '17Networks_LH_DefaultA_IPL_1',
#  '17Networks_LH_DefaultA_PFCd_1',
#  '17Networks_LH_DefaultA_pCunPCC_1',
#  '17Networks_LH_DefaultA_pCunPCC_2',
#  '17Networks_LH_DefaultA_pCunPCC_3',
#  '17Networks_LH_DefaultA_PFCm_1',
#  '17Networks_LH_DefaultA_PFCm_2',
#  '17Networks_LH_DefaultA_PFCm_3',
#  '17Networks_LH_DefaultB_Temp_1',
#  '17Networks_LH_DefaultB_Temp_2',
#  '17Networks_LH_DefaultB_Temp_3',
#  '17Networks_LH_DefaultB_Temp_4',
#  '17Networks_LH_DefaultB_IPL_1',
#  '17Networks_LH_DefaultB_PFCd_1',
#  '17Networks_LH_DefaultB_PFCd_2',
#  '17Networks_LH_DefaultB_PFCd_3',
#  '17Networks_LH_DefaultB_PFCd_4',
#  '17Networks_LH_DefaultB_PFCv_1',
#  '17Networks_LH_DefaultB_PFCv_2',
#  '17Networks_LH_DefaultB_PFCv_3',
#  '17Networks_LH_DefaultB_PFCv_4',
#  '17Networks_LH_DefaultC_IPL_1',
#  '17Networks_LH_DefaultC_Rsp_1',
#  '17Networks_LH_DefaultC_PHC_1',
#  '17Networks_LH_TempPar_1',
#  '17Networks_LH_TempPar_2',
#  '17Networks_RH_VisCent_ExStr_1',
#  '17Networks_RH_VisCent_ExStr_2',
#  '17Networks_RH_VisCent_Striate_1',
#  '17Networks_RH_VisCent_ExStr_3',
#  '17Networks_RH_VisCent_ExStr_4',
#  '17Networks_RH_VisCent_ExStr_5',
#  '17Networks_RH_VisPeri_ExStrInf_1',
#  '17Networks_RH_VisPeri_ExStrInf_2',
#  '17Networks_RH_VisPeri_StriCal_1',
#  '17Networks_RH_VisPeri_ExStrSup_1',
#  '17Networks_RH_VisPeri_ExStrSup_2',
#  '17Networks_RH_VisPeri_ExStrSup_3',
#  '17Networks_RH_SomMotA_1',
#  '17Networks_RH_SomMotA_2',
#  '17Networks_RH_SomMotA_3',
#  '17Networks_RH_SomMotA_4',
#  '17Networks_RH_SomMotA_5',
#  '17Networks_RH_SomMotA_6',
#  '17Networks_RH_SomMotA_7',
#  '17Networks_RH_SomMotA_8',
#  '17Networks_RH_SomMotA_9',
#  '17Networks_RH_SomMotA_10',
#  '17Networks_RH_SomMotA_11',
#  '17Networks_RH_SomMotB_Aud_1',
#  '17Networks_RH_SomMotB_Aud_2',
#  '17Networks_RH_SomMotB_S2_1',
#  '17Networks_RH_SomMotB_S2_2',
#  '17Networks_RH_SomMotB_S2_3',
#  '17Networks_RH_SomMotB_S2_4',
#  '17Networks_RH_SomMotB_Cent_1',
#  '17Networks_RH_DorsAttnA_TempOcc_1',
#  '17Networks_RH_DorsAttnA_ParOcc_1',
#  '17Networks_RH_DorsAttnA_SPL_1',
#  '17Networks_RH_DorsAttnA_SPL_2',
#  '17Networks_RH_DorsAttnA_SPL_3',
#  '17Networks_RH_DorsAttnA_SPL_4',
#  '17Networks_RH_DorsAttnB_PostC_1',
#  '17Networks_RH_DorsAttnB_PostC_2',
#  '17Networks_RH_DorsAttnB_PostC_3',
#  '17Networks_RH_DorsAttnB_PostC_4',
#  '17Networks_RH_DorsAttnB_FEF_1',
#  '17Networks_RH_SalVentAttnA_ParOper_1',
#  '17Networks_RH_SalVentAttnA_PrC_1',
#  '17Networks_RH_SalVentAttnA_Ins_1',
#  '17Networks_RH_SalVentAttnA_Ins_2',
#  '17Networks_RH_SalVentAttnA_FrOper_1',
#  '17Networks_RH_SalVentAttnA_FrMed_1',
#  '17Networks_RH_SalVentAttnA_ParMed_1',
#  '17Networks_RH_SalVentAttnA_ParMed_2',
#  '17Networks_RH_SalVentAttnA_FrMed_2',
#  '17Networks_RH_SalVentAttnB_IPL_1',
#  '17Networks_RH_SalVentAttnB_PFClv_1',
#  '17Networks_RH_SalVentAttnB_PFCl_1',
#  '17Networks_RH_SalVentAttnB_Ins_1',
#  '17Networks_RH_SalVentAttnB_Ins_2',
#  '17Networks_RH_SalVentAttnB_PFCmp_1',
#  '17Networks_RH_LimbicB_OFC_1',
#  '17Networks_RH_LimbicB_OFC_2',
#  '17Networks_RH_LimbicB_OFC_3',
#  '17Networks_RH_LimbicB_OFC_4',
#  '17Networks_RH_LimbicA_TempPole_1',
#  '17Networks_RH_LimbicA_TempPole_2',
#  '17Networks_RH_LimbicA_TempPole_3',
#  '17Networks_RH_LimbicA_TempPole_4',
#  '17Networks_RH_ContA_IPS_1',
#  '17Networks_RH_ContA_IPS_2',
#  '17Networks_RH_ContA_PFCd_1',
#  '17Networks_RH_ContA_PFCl_1',
#  '17Networks_RH_ContA_PFCl_2',
#  '17Networks_RH_ContA_Cingm_1',
#  '17Networks_RH_ContB_Temp_1',
#  '17Networks_RH_ContB_Temp_2',
#  '17Networks_RH_ContB_IPL_1',
#  '17Networks_RH_ContB_IPL_2',
#  '17Networks_RH_ContB_PFCld_1',
#  '17Networks_RH_ContB_PFCld_2',
#  '17Networks_RH_ContB_PFClv_1',
#  '17Networks_RH_ContB_PFClv_2',
#  '17Networks_RH_ContB_PFCmp_1',
#  '17Networks_RH_ContB_PFCld_3',
#  '17Networks_RH_ContC_pCun_1',
#  '17Networks_RH_ContC_pCun_2',
#  '17Networks_RH_ContC_Cingp_1',
#  '17Networks_RH_DefaultA_IPL_1',
#  '17Networks_RH_DefaultA_PFCd_1',
#  '17Networks_RH_DefaultA_pCunPCC_1',
#  '17Networks_RH_DefaultA_PFCm_1',
#  '17Networks_RH_DefaultA_PFCm_2',
#  '17Networks_RH_DefaultA_PFCm_3',
#  '17Networks_RH_DefaultB_Temp_1',
#  '17Networks_RH_DefaultB_AntTemp_1',
#  '17Networks_RH_DefaultB_PFCd_1',
#  '17Networks_RH_DefaultB_PFCv_1',
#  '17Networks_RH_DefaultC_IPL_1',
#  '17Networks_RH_DefaultC_Rsp_1',
#  '17Networks_RH_DefaultC_PHC_1',
#  '17Networks_RH_TempPar_1',
#  '17Networks_RH_TempPar_2',
#  '17Networks_RH_TempPar_3',
#  '17Networks_RH_TempPar_4']

# %%
netname_list = []
for name in name_list:
    if ("TempPar" in name) or ("SomMotA" in name):
        new_name = name.split("_")[:-1]
        net_name = '_'.join(new_name[-2:])
        print(net_name)
        netname_list.append(net_name)
    else:
        new_name = name.split("_")[:-2]
        net_name = '_'.join(new_name[-2:])
        print(net_name)
        netname_list.append(net_name)
# Out:
# LH_VisCent
# LH_VisCent
# LH_VisCent
# LH_VisCent
# LH_VisCent
# LH_VisCent
# LH_VisPeri
# LH_VisPeri
# LH_VisPeri
# LH_VisPeri
# LH_VisPeri
# LH_VisPeri
# LH_SomMotA
# LH_SomMotA
# LH_SomMotA
# LH_SomMotA
# LH_SomMotA
# LH_SomMotA
# LH_SomMotA
# LH_SomMotA
# LH_SomMotB
# LH_SomMotB
# LH_SomMotB
# LH_SomMotB
# LH_SomMotB
# LH_SomMotB
# LH_SomMotB
# LH_SomMotB
# LH_DorsAttnA
# LH_DorsAttnA
# LH_DorsAttnA
# LH_DorsAttnA
# LH_DorsAttnA
# LH_DorsAttnA
# LH_DorsAttnB
# LH_DorsAttnB
# LH_DorsAttnB
# LH_DorsAttnB
# LH_DorsAttnB
# LH_SalVentAttnA
# LH_SalVentAttnA
# LH_SalVentAttnA
# LH_SalVentAttnA
# LH_SalVentAttnA
# LH_SalVentAttnA
# LH_SalVentAttnA
# LH_SalVentAttnB
# LH_SalVentAttnB
# LH_SalVentAttnB
# LH_SalVentAttnB
# LH_LimbicB
# LH_LimbicB
# LH_LimbicA
# LH_LimbicA
# LH_LimbicA
# LH_LimbicA
# LH_ContA
# LH_ContA
# LH_ContA
# LH_ContA
# LH_ContA
# LH_ContA
# LH_ContA
# LH_ContA
# LH_ContA
# LH_ContA
# LH_ContB
# LH_ContB
# LH_ContB
# LH_ContB
# LH_ContB
# LH_ContC
# LH_ContC
# LH_ContC
# LH_DefaultA
# LH_DefaultA
# LH_DefaultA
# LH_DefaultA
# LH_DefaultA
# LH_DefaultA
# LH_DefaultA
# LH_DefaultA
# LH_DefaultB
# LH_DefaultB
# LH_DefaultB
# LH_DefaultB
# LH_DefaultB
# LH_DefaultB
# LH_DefaultB
# LH_DefaultB
# LH_DefaultB
# LH_DefaultB
# LH_DefaultB
# LH_DefaultB
# LH_DefaultB
# LH_DefaultC
# LH_DefaultC
# LH_DefaultC
# LH_TempPar
# LH_TempPar
# RH_VisCent
# RH_VisCent
# RH_VisCent
# RH_VisCent
# RH_VisCent
# RH_VisCent
# RH_VisPeri
# RH_VisPeri
# RH_VisPeri
# RH_VisPeri
# RH_VisPeri
# RH_VisPeri
# RH_SomMotA
# RH_SomMotA
# RH_SomMotA
# RH_SomMotA
# RH_SomMotA
# RH_SomMotA
# RH_SomMotA
# RH_SomMotA
# RH_SomMotA
# RH_SomMotA
# RH_SomMotA
# RH_SomMotB
# RH_SomMotB
# RH_SomMotB
# RH_SomMotB
# RH_SomMotB
# RH_SomMotB
# RH_SomMotB
# RH_DorsAttnA
# RH_DorsAttnA
# RH_DorsAttnA
# RH_DorsAttnA
# RH_DorsAttnA
# RH_DorsAttnA
# RH_DorsAttnB
# RH_DorsAttnB
# RH_DorsAttnB
# RH_DorsAttnB
# RH_DorsAttnB
# RH_SalVentAttnA
# RH_SalVentAttnA
# RH_SalVentAttnA
# RH_SalVentAttnA
# RH_SalVentAttnA
# RH_SalVentAttnA
# RH_SalVentAttnA
# RH_SalVentAttnA
# RH_SalVentAttnA
# RH_SalVentAttnB
# RH_SalVentAttnB
# RH_SalVentAttnB
# RH_SalVentAttnB
# RH_SalVentAttnB
# RH_SalVentAttnB
# RH_LimbicB
# RH_LimbicB
# RH_LimbicB
# RH_LimbicB
# RH_LimbicA
# RH_LimbicA
# RH_LimbicA
# RH_LimbicA
# RH_ContA
# RH_ContA
# RH_ContA
# RH_ContA
# RH_ContA
# RH_ContA
# RH_ContB
# RH_ContB
# RH_ContB
# RH_ContB
# RH_ContB
# RH_ContB
# RH_ContB
# RH_ContB
# RH_ContB
# RH_ContB
# RH_ContC
# RH_ContC
# RH_ContC
# RH_DefaultA
# RH_DefaultA
# RH_DefaultA
# RH_DefaultA
# RH_DefaultA
# RH_DefaultA
# RH_DefaultB
# RH_DefaultB
# RH_DefaultB
# RH_DefaultB
# RH_DefaultC
# RH_DefaultC
# RH_DefaultC
# RH_TempPar
# RH_TempPar
# RH_TempPar
# RH_TempPar

# %%
data["network"] = netname_list
data
# Out:
#      label_number                  label_full_name  mean w-score  \
# 0               1    17Networks_LH_VisCent_ExStr_1      0.813508
# 1               2    17Networks_LH_VisCent_ExStr_2      0.808221
# 2               3  17Networks_LH_VisCent_Striate_1      0.221304
# 3               4    17Networks_LH_VisCent_ExStr_3      0.954794
# 4               5    17Networks_LH_VisCent_ExStr_4      1.103241
# ..            ...                              ...           ...
# 195           196     17Networks_RH_DefaultC_PHC_1      0.020240
# 196           197          17Networks_RH_TempPar_1      0.370719
# 197           198          17Networks_RH_TempPar_2      0.502387
# 198           199          17Networks_RH_TempPar_3      0.735193
# 199           200          17Networks_RH_TempPar_4      0.484164
#
#      perc_suprathreshold      network
# 0                     15   LH_VisCent
# 1                     25   LH_VisCent
# 2                      0   LH_VisCent
# 3                     20   LH_VisCent
# 4                     20   LH_VisCent
# ..                   ...          ...
# 195                    0  RH_DefaultC
# 196                    5   RH_TempPar
# 197                   10   RH_TempPar
# 198                   25   RH_TempPar
# 199                   10   RH_TempPar
#
# [200 rows x 5 columns]

# %%
sns.scatterplot(data=data, x="mean w-score", y="perc_suprathreshold", hue="network", legend=False)
# Out:
# <AxesSubplot:xlabel='mean w-score', ylabel='perc_suprathreshold'>
