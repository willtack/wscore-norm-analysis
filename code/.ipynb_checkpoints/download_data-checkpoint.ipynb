# %%
import flywheel
import os
import datetime
from dateutil.tz import tzutc

fw = flywheel.Client()
project_id = '60fef55e60ec55d1b0e0741e'
local_dir = '../csvs'
os.makedirs(local_dir, exist_ok=True)

# %%
# Get all the sessions within the project.
sessions = [fw.get_session(x.id) for x in fw.get_project_sessions(project_id)]

# %%
for session in sessions:
    sub = session.subject
    if not 'Normal' in sub.tags:
        continue
        
    print(session.label)
    
    for analysis in session.analyses:
        if analysis.label.startswith('neuroprint') and analysis.job['state']=='complete' and analysis.files:
            print(analysis.label)
            csv_file = [f for f in analysis.files if f.name.endswith('csv') and 'wscore' in f.name][0]
            try:
                print("Downloading heatmaps...")
                analysis.download_file(csv_file.name, os.path.join(local_dir, csv_file.name))
                #analysis.download_file(png_files[1].name, os.path.join(local_dir, png_files[1].name))
            except IndexError as e:
                print(e)
                print("Could not download csv from {}.".format(session.label))
                
    print("")
# Out:
# 100049x20160621x3T
# neuroprint_2021-12-1_15:51_WT
# Downloading heatmaps...
# neuroprint_2022-2-16_16:47_WT
# Downloading heatmaps...
#
# 100113x20160620x3T
# neuroprint_2021-12-1_15:51_WT
# Downloading heatmaps...
# neuroprint_2022-2-16_16:47_WT
# Downloading heatmaps...
#
# 122216x20200205x3T
# neuroprint_2021-12-1_15:51_WT
# Downloading heatmaps...
# neuroprint_2022-2-16_16:47_WT
# Downloading heatmaps...
#
# 125687x20200714x3T
# neuroprint_2021-12-1_15:51_WT
# Downloading heatmaps...
# neuroprint_2022-2-16_16:47_WT
# Downloading heatmaps...
#
# 112286x01x20200721x3T
# neuroprint_2021-12-1_15:51_WT
# Downloading heatmaps...
# neuroprint_2022-2-16_16:47_WT
# Downloading heatmaps...
#
# 124509x20200813x3T
# neuroprint_2021-12-1_15:51_WT
# Downloading heatmaps...
# neuroprint_2022-2-16_16:47_WT
# Downloading heatmaps...
#
# 107486x20200929x3T
# neuroprint_2021-12-1_15:51_WT
# Downloading heatmaps...
# neuroprint_2022-2-16_16:47_WT
# Downloading heatmaps...
#
# 125564x20201105x3T
# neuroprint_2021-12-1_15:51_WT
# Downloading heatmaps...
# neuroprint_2022-2-16_16:47_WT
# Downloading heatmaps...
#
# 123831x20201201x3T
# neuroprint_2021-12-1_15:51_WT
# Downloading heatmaps...
# neuroprint_2022-2-16_16:47_WT
# Downloading heatmaps...
#
# 123575x20201015x3T
# neuroprint_2021-12-1_15:51_WT
# Downloading heatmaps...
# neuroprint_2022-2-16_16:47_WT
# Downloading heatmaps...
#
# 126022x20210112x3T
# neuroprint_2021-12-1_15:51_WT
# Downloading heatmaps...
# neuroprint_2022-2-16_16:47_WT
# Downloading heatmaps...
#
# 124822x20210126x3T
# neuroprint_2021-12-1_15:51_WT
# Downloading heatmaps...
# neuroprint_2022-2-16_16:47_WT
# Downloading heatmaps...
#
# 125780x20210216x3T
# neuroprint_2021-12-1_15:51_WT
# Downloading heatmaps...
# neuroprint_2022-2-16_16:47_WT
# Downloading heatmaps...
#
# 124568x20210318x3T
# neuroprint_2021-12-1_15:51_WT
# Downloading heatmaps...
# neuroprint_2022-2-16_16:47_WT
# Downloading heatmaps...
#
# 125572x20210323x3T
# neuroprint_2021-12-1_15:51_WT
# Downloading heatmaps...
# neuroprint_2022-2-16_16:47_WT
# Downloading heatmaps...
#
# 113066x02x20210427x3T
# neuroprint_2021-12-1_15:51_WT
# Downloading heatmaps...
# neuroprint_2022-2-16_16:47_WT
# Downloading heatmaps...
#
# 122946x20210427x3T
# neuroprint_2021-12-1_15:51_WT
# Downloading heatmaps...
# neuroprint_2022-2-16_16:47_WT
# Downloading heatmaps...
#
# 124972x20210525x3T
# neuroprint_2021-12-1_15:51_WT
# Downloading heatmaps...
# neuroprint_2022-2-16_16:47_WT
# Downloading heatmaps...
#
# 124938x20210527x3T
# neuroprint_2021-12-1_15:51_WT
# Downloading heatmaps...
# neuroprint_2022-2-16_16:47_WT
# Downloading heatmaps...
#
# 125987x20210610x3T
# neuroprint_2021-12-1_15:51_WT
# Downloading heatmaps...
# neuroprint_2022-2-16_16:47_WT
# Downloading heatmaps...

# %% [markdown]
# ## Concatenate CSVs

# %%
from pathlib import Path
import pandas as pd
sheets = Path(local_dir).glob("*.csv")
sheets_strings = [str(p) for p in sheets]

df = pd.read_csv(sheets_strings[0])
df = df.drop("label_full_name",1)
df.set_index("label_number")

new_col_list = []
for sheet in sheets_strings[1:]:
    wscores = sheet['w-score']
    column_name = sheet.stem
    col_df = pd.DataFrame([wscores], columns=column_name)
    new_col_list.append(col_df)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-28-5517991afa00> in <module>
#       9
#      10 new_col_list = []
# ---> 11 for sheet in sheets[1:]:
#      12     wscores = sheet['w-score']
#      13     column_name = sheet.stem
#
# TypeError: 'generator' object is not subscriptable

# %%
# Out:
#                w-score
# label_number
# 1             1.076187
# 2             1.591047
# 3             1.041013
# 4             1.687107
# 5             1.352005
# ...                ...
# 196          -0.232103
# 197           1.051083
# 198           0.741301
# 199           0.645178
# 200           1.118519
#
# [200 rows x 1 columns]
